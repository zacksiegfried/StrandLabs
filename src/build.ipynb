# %%
from scipy.stats import binom

p_score = binom.pmf(alt_duplex, total_duplex, alt_duplex/total_duplex)*0.5/binom.pmf(alt_duplex, total_duplex, alt_duplex/total_duplex)*0.5+ binom.pmf(alt_duplex, total_duplex, noise_floor)*0.5
# 0.5 terms cancel out
# left in for replacement with P(MRD+) or P(MRD-) probabilities that can be calcualted with an imformative prior test MRD+
# Not sure if there is ever a scenario where this would be used
